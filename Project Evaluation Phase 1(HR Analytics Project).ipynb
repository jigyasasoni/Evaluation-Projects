# %% [markdown]
# # Evaluation Project Phase 1 ( HR Analytics Project ) - Understanding the Attrition in HR

# %% [markdown]
# # By :- JIGYASA SONI

# %% [markdown]
# # Batch DS2309

# %% [markdown]
# # Problem Statement:

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# # HR Analytics:

# %% [markdown]
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# # Attrition in HR:

# %% [markdown]
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.

# %% [markdown]
# How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.

# %% [markdown]
# # Attrition affecting Companies:

# %% [markdown]
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %% [markdown]
# # Note: You can find the dataset in the link below.

# %% [markdown]
# Downlaod Files:
#
# https://github.com/dsrscientist/IBM_HR_Attrition_Rate_Analytics

# %% [markdown]
# #  . Importing require library for performing EDA, Data Wrangling and data cleaning

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
pd.set_option('display.max_columns', None) 
df.head()
# Out:
# No of Rows: 1470
# No of Columns: 35
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'], object: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']}

# %% [markdown]
# # Comment:-

# %% [markdown]
#  . In this HR dataset we have 1470 rows and 35 columns.
#
#  . Non-null count is same for all Columns, so it seem that it contain No missing value. Still we need to perform Data integrity Check for null values in form of "-","NA" , any duplicate entry or error in Data.
#
#  . Out of 35 we have 9 features with Object datatypes and rest are int64 types
#
#  . Among all Numeric Variables 'Education','EnvironmentSatisfaction', 'JobInvolvement', 'JobSatisfaction', 'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' are ordinal variable. Unique range of all these ordinal Variable need to check.
#
#  . Here We have Target Variable 'Attrition'.

# %% [markdown]
# ### . These Ordinal features come with the following label encoding:

# %% [markdown]
# ##### Education: 1- 'Below College' , 2 -'College', 3 -'Bachelor', 4- 'Master' ,5 -'Doctor'
# EnvironmentSatisfaction: 1- 'Low', 2- 'Medium', 3 -'High', 4- 'Very High'
# JobInvolvement: 1 -'Low', 2- 'Medium', 3- 'High', 4- 'Very High'
# JobSatisfaction: 1- 'Low', 2- 'Medium', 3- 'High', 4 -'Very High'
# PerformanceRating: 1- 'Low', 2- 'Average', 3 -'Good', 4- 'Excellent', 5- 'Outstanding'
# RelationshipSatisfaction: 1- 'Low', 2- 'Medium', 3- 'High', 4- 'Very High'
# WorkLifeBalance: 1- 'Bad', 2- 'Good', 3- 'Better', 4- 'Best'

# %% [markdown]
# ## Statistical Analysis

# %% [markdown]
# ### Before Going for Statistical exploration of data, first check integrity of data & Missing value

# %% [markdown]
# ## Data Integrity Check

# %% [markdown]
# #### Since dataset is large, Let check for any entry which is repeated or duplicated in dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Missing Value Check

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                           Missing Values  % Missing data
# Age                                    0             0.0
# StandardHours                          0             0.0
# NumCompaniesWorked                     0             0.0
# Over18                                 0             0.0
# OverTime                               0             0.0
# PercentSalaryHike                      0             0.0
# PerformanceRating                      0             0.0
# RelationshipSatisfaction               0             0.0
# StockOptionLevel                       0             0.0
# MonthlyIncome                          0             0.0
# TotalWorkingYears                      0             0.0
# TrainingTimesLastYear                  0             0.0
# WorkLifeBalance                        0             0.0
# YearsAtCompany                         0             0.0
# YearsInCurrentRole                     0             0.0
# YearsSinceLastPromotion                0             0.0
# MonthlyRate                            0             0.0
# MaritalStatus                          0             0.0
# Attrition                              0             0.0
# EmployeeCount                          0             0.0
# BusinessTravel                         0             0.0
# DailyRate                              0             0.0
# Department                             0             0.0
# DistanceFromHome                       0             0.0
# Education                              0             0.0
# EducationField                         0             0.0
# EmployeeNumber                         0             0.0
# JobSatisfaction                        0             0.0
# EnvironmentSatisfaction                0             0.0
# Gender                                 0             0.0
# HourlyRate                             0             0.0
# JobInvolvement                         0             0.0
# JobLevel                               0             0.0
# JobRole                                0             0.0
# YearsWithCurrManager                   0             0.0

# %% [markdown]
# ## Comment:-

# %% [markdown]
# Luckily for us, there is no missing data! this will make it easier to work with the dataset.
#
# Dataset doesnot contain Any duplicate entry, Missing Values.

# %% [markdown]
# #### So, Yes To Go !!!

# %% [markdown]
# ## Statistical Matrix

# %%
plt.figure(figsize=(28,10))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
df.describe().T.round(3)
# Out:
#                            count       mean       std     min      25%  \
# Age                       1470.0     36.924     9.135    18.0    30.00
# DailyRate                 1470.0    802.486   403.509   102.0   465.00
# DistanceFromHome          1470.0      9.193     8.107     1.0     2.00
# Education                 1470.0      2.913     1.024     1.0     2.00
# EmployeeCount             1470.0      1.000     0.000     1.0     1.00
# EmployeeNumber            1470.0   1024.865   602.024     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.722     1.093     1.0     2.00
# HourlyRate                1470.0     65.891    20.329    30.0    48.00
# JobInvolvement            1470.0      2.730     0.712     1.0     2.00
# JobLevel                  1470.0      2.064     1.107     1.0     1.00
# JobSatisfaction           1470.0      2.729     1.103     1.0     2.00
# MonthlyIncome             1470.0   6502.931  4707.957  1009.0  2911.00
# MonthlyRate               1470.0  14313.103  7117.786  2094.0  8047.00
# NumCompaniesWorked        1470.0      2.693     2.498     0.0     1.00
# PercentSalaryHike         1470.0     15.210     3.660    11.0    12.00
# PerformanceRating         1470.0      3.154     0.361     3.0     3.00
# RelationshipSatisfaction  1470.0      2.712     1.081     1.0     2.00
# StandardHours             1470.0     80.000     0.000    80.0    80.00
# StockOptionLevel          1470.0      0.794     0.852     0.0     0.00
# TotalWorkingYears         1470.0     11.280     7.781     0.0     6.00
# TrainingTimesLastYear     1470.0      2.799     1.289     0.0     2.00
# WorkLifeBalance           1470.0      2.761     0.706     1.0     2.00
# YearsAtCompany            1470.0      7.008     6.127     0.0     3.00
# YearsInCurrentRole        1470.0      4.229     3.623     0.0     2.00
# YearsSinceLastPromotion   1470.0      2.188     3.222     0.0     0.00
# YearsWithCurrManager      1470.0      4.123     3.568     0.0     2.00
#
#                               50%       75%      max
# Age                          36.0     43.00     60.0
# DailyRate                   802.0   1157.00   1499.0
# DistanceFromHome              7.0     14.00     29.0
# Education                     3.0      4.00      5.0
# EmployeeCount                 1.0      1.00      1.0
# EmployeeNumber             1020.5   1555.75   2068.0
# EnvironmentSatisfaction       3.0      4.00      4.0
# HourlyRate                   66.0     83.75    100.0
# JobInvolvement                3.0      3.00      4.0
# JobLevel                      2.0      3.00      5.0
# JobSatisfaction               3.0      4.00      4.0
# MonthlyIncome              4919.0   8379.00  19999.0
# MonthlyRate               14235.5  20461.50  26999.0
# NumCompaniesWorked            2.0      4.00      9.0
# PercentSalaryHike            14.0     18.00     25.0
# PerformanceRating             3.0      3.00      4.0
# RelationshipSatisfaction      3.0      4.00      4.0
# StandardHours                80.0     80.00     80.0
# StockOptionLevel              1.0      1.00      3.0
# TotalWorkingYears            10.0     15.00     40.0
# TrainingTimesLastYear         3.0      3.00      6.0
# WorkLifeBalance               3.0      3.00      4.0
# YearsAtCompany                5.0      9.00     40.0
# YearsInCurrentRole            3.0      7.00     18.0
# YearsSinceLastPromotion       1.0      3.00     15.0
# YearsWithCurrManager          3.0      7.00     17.0

# %% [markdown]
# ## Comment:-

# %% [markdown]
#  . Minimum Empolyee Age is 18 and Maximum age of employee 60.
#
#  . Average distance from home is 9.1 KM. It means that most of employee travel atleast 18 KM in day from home to office.
#
#  . On Average performance Rating of employees is 3.163 with min value 3.0. This Means that performance of most of employee is 'Good'.This implies that Attrition of Employee with 'Outstanding' or 5 rating need to investigate.
#
#  . 50% of Employees has worked atleast 2 companies previously.
#
#  . For Monthly Income,Monthly Rate by looking at 50% and max column we can say outliers exist in this feature.
#
#  . By looking at Mean and Median we see that some of the features are skew in nature.
#
#  . For ordinal features statstical terminology of mean, median, std deviation doesnot make sense.
#
#  . StandardHours and EmployeeCount contain same value for all stastical parameter. It means they contain one unique value.

# %% [markdown]
# #
#     . Lets do some Statistical Analysis. Start with target Variable.

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
labels='Yes','No',
fig,ax = plt.subplots()
ax.pie(df['Attrition'].value_counts(),labels= labels,radius=2, autopct= '%2.2f%%', explode=[0.1,0.2], shadow=True)
plt.show()

# %% [markdown]
# # Comment:-

# %% [markdown]
#  . 83.88% (1237 employees) Employees did not leave the organization while 16.12% (237 employees) did leave the organization     making our dataset to be considered imbalanced since more people stay in the organization than they actually leave.

# %% [markdown]
# ## Before arrive at key questions which need to answer about HR Attrition, let try to gain some insight about individual features like distribution of different subcategories, different insight about Human Resource in company like education,job level, working domain.

# %% [markdown]
# ### Start with Enlisting Value counts & Sub-categories of different categorial features available

# %%
Category=['Attrition', 'BusinessTravel', 'Department', 'EducationField',
         'Gender', 'JobRole',  'Over18', 'OverTime']
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# Attrition
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# ====================================================================================================
# BusinessTravel
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64
# ====================================================================================================
# Department
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64
# ====================================================================================================
# EducationField
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64
# ====================================================================================================
# Gender
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64
# ====================================================================================================
# JobRole
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64
# ====================================================================================================
# Over18
# Over18
# Y    1470
# Name: count, dtype: int64
# ====================================================================================================
# OverTime
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64
# ====================================================================================================

# %%
if 'MaritalStatus' in df.columns:
    print(df['MaritalStatus'].value_counts())
    print("="*100)
else:
    print("Column 'MaritalStatus' not found in the DataFrame.")
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64
# ====================================================================================================

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
Category=['Attrition', 'BusinessTravel', 'Department', 'EducationField',
          'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime' ]
for i in Category:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(data=df, x=i,palette='Set1' )
        plt.xlabel(i,fontsize=20)
        plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Enlisting Value counts & Sub-categories of different Ordinal features available

# %%
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
         'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    print(i)
    print(df[i].value_counts())
    print("="*100)
# Out:
# Education
# Education
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: count, dtype: int64
# ====================================================================================================
# EnvironmentSatisfaction
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64
# ====================================================================================================
# JobInvolvement
# JobInvolvement
# 3    868
# 2    375
# 4    144
# 1     83
# Name: count, dtype: int64
# ====================================================================================================
# JobSatisfaction
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64
# ====================================================================================================
# RelationshipSatisfaction
# RelationshipSatisfaction
# 3    459
# 4    432
# 2    303
# 1    276
# Name: count, dtype: int64
# ====================================================================================================
# PerformanceRating
# PerformanceRating
# 3    1244
# 4     226
# Name: count, dtype: int64
# ====================================================================================================
# WorkLifeBalance
# WorkLifeBalance
# 3    893
# 2    344
# 4    153
# 1     80
# Name: count, dtype: int64
# ====================================================================================================

# %%
sns.set_palette('hsv')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
Ordinal=['Education','EnvironmentSatisfaction', 'JobInvolvement','JobSatisfaction',
          'RelationshipSatisfaction', 'PerformanceRating', 'WorkLifeBalance' ]
for i in Ordinal:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.countplot(data=df, x=i , palette='Set1')
        plt.xlabel(i,fontsize=20)
        plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Education level of Man power available

# %%
labels='Bachelor','Master','College','Below College','Doctor'
fig, ax = plt.subplots()
ax.pie(df['Education'].value_counts(),labels = labels,radius =2,autopct = '%3.2f%%',explode=[0.1,0.1,0.15,0.2,0.3], shadow=True,)
plt.show()

# %% [markdown]
# ### Comment:

# %% [markdown]
#  . More than 60 % employees educated at Masters & Bachelor. It interesting to find out in which department need this human resources.
#
#  . 30 % of Employees are highly educated which involves master and doctor degree.
#
#  . 39 % of Employees are graduate.
#
#  . Almost 19% Employees are educated upto college & 12% are below college.

# %% [markdown]
# ### Lets try to gain insight on to which department this Human Resource belong and education need of each department through visualization.

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
labels ='Research & Development','Sales','Human Resources'
fig,ax= plt.subplots()
ax.pie(df['Department'].value_counts(),labels=labels, radius=2,autopct= '%3.2f%%',explode=[0.1,0.15,0.2],shadow=True)
plt.show()

# %%
pd.crosstab([df.Education],[df.Department], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_9e658_row0_col0 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_9e658_row0_col1 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_9e658_row0_col2 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_9e658_row0_col3 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_9e658_row1_col0, #T_9e658_row1_col2, #T_9e658_row1_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_9e658_row1_col1 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_9e658_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_9e658_row2_col1 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_9e658_row2_col2 {
#   background-color: #a6d266;
#   color: #000000;
# }
# #T_9e658_row2_col3 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_9e658_row3_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_9e658_row3_col1 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_9e658_row3_col2 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_9e658_row3_col3 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_9e658_row4_col0, #T_9e658_row4_col1, #T_9e658_row4_col2, #T_9e658_row4_col3 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_9e658_row5_col0, #T_9e658_row5_col1, #T_9e658_row5_col2, #T_9e658_row5_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e658">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_9e658_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_9e658_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_9e658_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_9e658_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e658_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_9e658_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_9e658_row0_col1" class="data row0 col1" >115</td>
#       <td id="T_9e658_row0_col2" class="data row0 col2" >50</td>
#       <td id="T_9e658_row0_col3" class="data row0 col3" >170</td>
#     </tr>
#     <tr>
#       <th id="T_9e658_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_9e658_row1_col0" class="data row1 col0" >13</td>
#       <td id="T_9e658_row1_col1" class="data row1 col1" >182</td>
#       <td id="T_9e658_row1_col2" class="data row1 col2" >87</td>
#       <td id="T_9e658_row1_col3" class="data row1 col3" >282</td>
#     </tr>
#     <tr>
#       <th id="T_9e658_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_9e658_row2_col0" class="data row2 col0" >27</td>
#       <td id="T_9e658_row2_col1" class="data row2 col1" >379</td>
#       <td id="T_9e658_row2_col2" class="data row2 col2" >166</td>
#       <td id="T_9e658_row2_col3" class="data row2 col3" >572</td>
#     </tr>
#     <tr>
#       <th id="T_9e658_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9e658_row3_col0" class="data row3 col0" >15</td>
#       <td id="T_9e658_row3_col1" class="data row3 col1" >255</td>
#       <td id="T_9e658_row3_col2" class="data row3 col2" >128</td>
#       <td id="T_9e658_row3_col3" class="data row3 col3" >398</td>
#     </tr>
#     <tr>
#       <th id="T_9e658_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_9e658_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_9e658_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_9e658_row4_col2" class="data row4 col2" >15</td>
#       <td id="T_9e658_row4_col3" class="data row4 col3" >48</td>
#     </tr>
#     <tr>
#       <th id="T_9e658_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_9e658_row5_col0" class="data row5 col0" >63</td>
#       <td id="T_9e658_row5_col1" class="data row5 col1" >961</td>
#       <td id="T_9e658_row5_col2" class="data row5 col2" >446</td>
#       <td id="T_9e658_row5_col3" class="data row5 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Comment :-

# %% [markdown]
#  . 65.37% of Employees belong to Research & Development Department. Out of Total 961 Employee no of employee educated at Bachelors,Masters, Doctor are 379,255 and 30 respectively.
#
#
#  . Only 63 Employee work in HR department.

# %%
pd.crosstab([df.Education],[df.Department,df.Attrition], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_eb952_row0_col0 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# #T_eb952_row0_col1, #T_eb952_row4_col0, #T_eb952_row4_col1, #T_eb952_row4_col2, #T_eb952_row4_col3, #T_eb952_row4_col4, #T_eb952_row4_col5, #T_eb952_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_eb952_row0_col2 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_eb952_row0_col3 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_eb952_row0_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_eb952_row0_col5 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_eb952_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_eb952_row1_col0, #T_eb952_row1_col4 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# #T_eb952_row1_col1, #T_eb952_row3_col1 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_eb952_row1_col2, #T_eb952_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_eb952_row1_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_eb952_row1_col5 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_eb952_row2_col0 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_eb952_row2_col1 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_eb952_row2_col2, #T_eb952_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_eb952_row2_col3 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_eb952_row2_col4 {
#   background-color: #aad466;
#   color: #000000;
# }
# #T_eb952_row2_col5 {
#   background-color: #95ca66;
#   color: #000000;
# }
# #T_eb952_row3_col0 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_eb952_row3_col2 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_eb952_row3_col3 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_eb952_row3_col4 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_eb952_row3_col5 {
#   background-color: #c2e066;
#   color: #000000;
# }
# #T_eb952_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_eb952_row5_col0, #T_eb952_row5_col1, #T_eb952_row5_col2, #T_eb952_row5_col3, #T_eb952_row5_col4, #T_eb952_row5_col5, #T_eb952_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_eb952">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_eb952_level0_col0" class="col_heading level0 col0" colspan="2">Human Resources</th>
#       <th id="T_eb952_level0_col2" class="col_heading level0 col2" colspan="2">Research & Development</th>
#       <th id="T_eb952_level0_col4" class="col_heading level0 col4" colspan="2">Sales</th>
#       <th id="T_eb952_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Attrition</th>
#       <th id="T_eb952_level1_col0" class="col_heading level1 col0" >No</th>
#       <th id="T_eb952_level1_col1" class="col_heading level1 col1" >Yes</th>
#       <th id="T_eb952_level1_col2" class="col_heading level1 col2" >No</th>
#       <th id="T_eb952_level1_col3" class="col_heading level1 col3" >Yes</th>
#       <th id="T_eb952_level1_col4" class="col_heading level1 col4" >No</th>
#       <th id="T_eb952_level1_col5" class="col_heading level1 col5" >Yes</th>
#       <th id="T_eb952_level1_col6" class="col_heading level1 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb952_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_eb952_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_eb952_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_eb952_row0_col2" class="data row0 col2" >96</td>
#       <td id="T_eb952_row0_col3" class="data row0 col3" >19</td>
#       <td id="T_eb952_row0_col4" class="data row0 col4" >39</td>
#       <td id="T_eb952_row0_col5" class="data row0 col5" >11</td>
#       <td id="T_eb952_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_eb952_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_eb952_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_eb952_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_eb952_row1_col2" class="data row1 col2" >159</td>
#       <td id="T_eb952_row1_col3" class="data row1 col3" >23</td>
#       <td id="T_eb952_row1_col4" class="data row1 col4" >69</td>
#       <td id="T_eb952_row1_col5" class="data row1 col5" >18</td>
#       <td id="T_eb952_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_eb952_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_eb952_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_eb952_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_eb952_row2_col2" class="data row2 col2" >323</td>
#       <td id="T_eb952_row2_col3" class="data row2 col3" >56</td>
#       <td id="T_eb952_row2_col4" class="data row2 col4" >127</td>
#       <td id="T_eb952_row2_col5" class="data row2 col5" >39</td>
#       <td id="T_eb952_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_eb952_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_eb952_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_eb952_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_eb952_row3_col2" class="data row3 col2" >223</td>
#       <td id="T_eb952_row3_col3" class="data row3 col3" >32</td>
#       <td id="T_eb952_row3_col4" class="data row3 col4" >105</td>
#       <td id="T_eb952_row3_col5" class="data row3 col5" >23</td>
#       <td id="T_eb952_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_eb952_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_eb952_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_eb952_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_eb952_row4_col2" class="data row4 col2" >27</td>
#       <td id="T_eb952_row4_col3" class="data row4 col3" >3</td>
#       <td id="T_eb952_row4_col4" class="data row4 col4" >14</td>
#       <td id="T_eb952_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_eb952_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_eb952_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_eb952_row5_col0" class="data row5 col0" >51</td>
#       <td id="T_eb952_row5_col1" class="data row5 col1" >12</td>
#       <td id="T_eb952_row5_col2" class="data row5 col2" >828</td>
#       <td id="T_eb952_row5_col3" class="data row5 col3" >133</td>
#       <td id="T_eb952_row5_col4" class="data row5 col4" >354</td>
#       <td id="T_eb952_row5_col5" class="data row5 col5" >92</td>
#       <td id="T_eb952_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Employee distribution as per education field and level of education

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
labels ='Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources'
fig,ax= plt.subplots()
ax.pie(df['EducationField'].value_counts(),labels=labels, radius=2,autopct= '%3.2f%%',explode=[0.1,0.1,0.125,0.15,0.15,0.175],shadow=True)
plt.show()

# %%
pd.crosstab([df.Education],[df.EducationField], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_74b87_row0_col0, #T_74b87_row1_col0, #T_74b87_row4_col0, #T_74b87_row4_col1, #T_74b87_row4_col2, #T_74b87_row4_col3, #T_74b87_row4_col4, #T_74b87_row4_col5, #T_74b87_row4_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_74b87_row0_col1, #T_74b87_row0_col6 {
#   background-color: #eaf466;
#   color: #000000;
# }
# #T_74b87_row0_col2 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_74b87_row0_col3 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_74b87_row0_col4 {
#   background-color: #f3f966;
#   color: #000000;
# }
# #T_74b87_row0_col5 {
#   background-color: #e0f066;
#   color: #000000;
# }
# #T_74b87_row1_col1 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_74b87_row1_col2 {
#   background-color: #e7f366;
#   color: #000000;
# }
# #T_74b87_row1_col3 {
#   background-color: #d0e866;
#   color: #000000;
# }
# #T_74b87_row1_col4 {
#   background-color: #c7e366;
#   color: #000000;
# }
# #T_74b87_row1_col5 {
#   background-color: #daec66;
#   color: #000000;
# }
# #T_74b87_row1_col6 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_74b87_row2_col0 {
#   background-color: #70b866;
#   color: #f1f1f1;
# }
# #T_74b87_row2_col1 {
#   background-color: #a2d066;
#   color: #000000;
# }
# #T_74b87_row2_col2 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_74b87_row2_col3 {
#   background-color: #a0d066;
#   color: #000000;
# }
# #T_74b87_row2_col4, #T_74b87_row3_col2 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_74b87_row2_col5 {
#   background-color: #94ca66;
#   color: #000000;
# }
# #T_74b87_row2_col6 {
#   background-color: #a1d066;
#   color: #000000;
# }
# #T_74b87_row3_col0 {
#   background-color: #e1f066;
#   color: #000000;
# }
# #T_74b87_row3_col1 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_74b87_row3_col3 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_74b87_row3_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_74b87_row3_col5 {
#   background-color: #c8e366;
#   color: #000000;
# }
# #T_74b87_row3_col6 {
#   background-color: #c0e066;
#   color: #000000;
# }
# #T_74b87_row5_col0, #T_74b87_row5_col1, #T_74b87_row5_col2, #T_74b87_row5_col3, #T_74b87_row5_col4, #T_74b87_row5_col5, #T_74b87_row5_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_74b87">
#   <thead>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th id="T_74b87_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_74b87_level0_col1" class="col_heading level0 col1" >Life Sciences</th>
#       <th id="T_74b87_level0_col2" class="col_heading level0 col2" >Marketing</th>
#       <th id="T_74b87_level0_col3" class="col_heading level0 col3" >Medical</th>
#       <th id="T_74b87_level0_col4" class="col_heading level0 col4" >Other</th>
#       <th id="T_74b87_level0_col5" class="col_heading level0 col5" >Technical Degree</th>
#       <th id="T_74b87_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Education</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74b87_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_74b87_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_74b87_row0_col1" class="data row0 col1" >67</td>
#       <td id="T_74b87_row0_col2" class="data row0 col2" >14</td>
#       <td id="T_74b87_row0_col3" class="data row0 col3" >63</td>
#       <td id="T_74b87_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_74b87_row0_col5" class="data row0 col5" >19</td>
#       <td id="T_74b87_row0_col6" class="data row0 col6" >170</td>
#     </tr>
#     <tr>
#       <th id="T_74b87_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_74b87_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_74b87_row1_col1" class="data row1 col1" >116</td>
#       <td id="T_74b87_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_74b87_row1_col3" class="data row1 col3" >99</td>
#       <td id="T_74b87_row1_col4" class="data row1 col4" >19</td>
#       <td id="T_74b87_row1_col5" class="data row1 col5" >22</td>
#       <td id="T_74b87_row1_col6" class="data row1 col6" >282</td>
#     </tr>
#     <tr>
#       <th id="T_74b87_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_74b87_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_74b87_row2_col1" class="data row2 col1" >233</td>
#       <td id="T_74b87_row2_col2" class="data row2 col2" >59</td>
#       <td id="T_74b87_row2_col3" class="data row2 col3" >183</td>
#       <td id="T_74b87_row2_col4" class="data row2 col4" >24</td>
#       <td id="T_74b87_row2_col5" class="data row2 col5" >57</td>
#       <td id="T_74b87_row2_col6" class="data row2 col6" >572</td>
#     </tr>
#     <tr>
#       <th id="T_74b87_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_74b87_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_74b87_row3_col1" class="data row3 col1" >173</td>
#       <td id="T_74b87_row3_col2" class="data row3 col2" >52</td>
#       <td id="T_74b87_row3_col3" class="data row3 col3" >104</td>
#       <td id="T_74b87_row3_col4" class="data row3 col4" >33</td>
#       <td id="T_74b87_row3_col5" class="data row3 col5" >31</td>
#       <td id="T_74b87_row3_col6" class="data row3 col6" >398</td>
#     </tr>
#     <tr>
#       <th id="T_74b87_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_74b87_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_74b87_row4_col1" class="data row4 col1" >17</td>
#       <td id="T_74b87_row4_col2" class="data row4 col2" >10</td>
#       <td id="T_74b87_row4_col3" class="data row4 col3" >15</td>
#       <td id="T_74b87_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_74b87_row4_col5" class="data row4 col5" >3</td>
#       <td id="T_74b87_row4_col6" class="data row4 col6" >48</td>
#     </tr>
#     <tr>
#       <th id="T_74b87_level0_row5" class="row_heading level0 row5" >All</th>
#       <td id="T_74b87_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_74b87_row5_col1" class="data row5 col1" >606</td>
#       <td id="T_74b87_row5_col2" class="data row5 col2" >159</td>
#       <td id="T_74b87_row5_col3" class="data row5 col3" >464</td>
#       <td id="T_74b87_row5_col4" class="data row5 col4" >82</td>
#       <td id="T_74b87_row5_col5" class="data row5 col5" >132</td>
#       <td id="T_74b87_row5_col6" class="data row5 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.crosstab([df.Department],[df.EducationField], margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_88ed4_row0_col0, #T_88ed4_row2_col2, #T_88ed4_row3_col0, #T_88ed4_row3_col1, #T_88ed4_row3_col2, #T_88ed4_row3_col3, #T_88ed4_row3_col4, #T_88ed4_row3_col5, #T_88ed4_row3_col6 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_88ed4_row0_col1, #T_88ed4_row0_col2, #T_88ed4_row0_col3, #T_88ed4_row0_col4, #T_88ed4_row0_col5, #T_88ed4_row0_col6, #T_88ed4_row1_col0, #T_88ed4_row1_col2, #T_88ed4_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_88ed4_row1_col1 {
#   background-color: #48a366;
#   color: #f1f1f1;
# }
# #T_88ed4_row1_col3 {
#   background-color: #399c66;
#   color: #f1f1f1;
# }
# #T_88ed4_row1_col4 {
#   background-color: #3a9c66;
#   color: #f1f1f1;
# }
# #T_88ed4_row1_col5 {
#   background-color: #4ba566;
#   color: #f1f1f1;
# }
# #T_88ed4_row1_col6 {
#   background-color: #5cae66;
#   color: #f1f1f1;
# }
# #T_88ed4_row2_col1 {
#   background-color: #c5e266;
#   color: #000000;
# }
# #T_88ed4_row2_col3 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_88ed4_row2_col4 {
#   background-color: #d9ec66;
#   color: #000000;
# }
# #T_88ed4_row2_col5 {
#   background-color: #c3e166;
#   color: #000000;
# }
# #T_88ed4_row2_col6 {
#   background-color: #badc66;
#   color: #000000;
# }
# </style>
# <table id="T_88ed4">
#   <thead>
#     <tr>
#       <th class="index_name level0" >EducationField</th>
#       <th id="T_88ed4_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_88ed4_level0_col1" class="col_heading level0 col1" >Life Sciences</th>
#       <th id="T_88ed4_level0_col2" class="col_heading level0 col2" >Marketing</th>
#       <th id="T_88ed4_level0_col3" class="col_heading level0 col3" >Medical</th>
#       <th id="T_88ed4_level0_col4" class="col_heading level0 col4" >Other</th>
#       <th id="T_88ed4_level0_col5" class="col_heading level0 col5" >Technical Degree</th>
#       <th id="T_88ed4_level0_col6" class="col_heading level0 col6" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88ed4_level0_row0" class="row_heading level0 row0" >Human Resources</th>
#       <td id="T_88ed4_row0_col0" class="data row0 col0" >27</td>
#       <td id="T_88ed4_row0_col1" class="data row0 col1" >16</td>
#       <td id="T_88ed4_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_88ed4_row0_col3" class="data row0 col3" >13</td>
#       <td id="T_88ed4_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_88ed4_row0_col5" class="data row0 col5" >4</td>
#       <td id="T_88ed4_row0_col6" class="data row0 col6" >63</td>
#     </tr>
#     <tr>
#       <th id="T_88ed4_level0_row1" class="row_heading level0 row1" >Research & Development</th>
#       <td id="T_88ed4_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_88ed4_row1_col1" class="data row1 col1" >440</td>
#       <td id="T_88ed4_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_88ed4_row1_col3" class="data row1 col3" >363</td>
#       <td id="T_88ed4_row1_col4" class="data row1 col4" >64</td>
#       <td id="T_88ed4_row1_col5" class="data row1 col5" >94</td>
#       <td id="T_88ed4_row1_col6" class="data row1 col6" >961</td>
#     </tr>
#     <tr>
#       <th id="T_88ed4_level0_row2" class="row_heading level0 row2" >Sales</th>
#       <td id="T_88ed4_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_88ed4_row2_col1" class="data row2 col1" >150</td>
#       <td id="T_88ed4_row2_col2" class="data row2 col2" >159</td>
#       <td id="T_88ed4_row2_col3" class="data row2 col3" >88</td>
#       <td id="T_88ed4_row2_col4" class="data row2 col4" >15</td>
#       <td id="T_88ed4_row2_col5" class="data row2 col5" >34</td>
#       <td id="T_88ed4_row2_col6" class="data row2 col6" >446</td>
#     </tr>
#     <tr>
#       <th id="T_88ed4_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_88ed4_row3_col0" class="data row3 col0" >27</td>
#       <td id="T_88ed4_row3_col1" class="data row3 col1" >606</td>
#       <td id="T_88ed4_row3_col2" class="data row3 col2" >159</td>
#       <td id="T_88ed4_row3_col3" class="data row3 col3" >464</td>
#       <td id="T_88ed4_row3_col4" class="data row3 col4" >82</td>
#       <td id="T_88ed4_row3_col5" class="data row3 col5" >132</td>
#       <td id="T_88ed4_row3_col6" class="data row3 col6" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comment:

# %% [markdown]
#  . 41.22 % Employee comes from Life science background followed by Medical profession with 31.56%.
#
#  . There are only 27 people with HR background and We know that 63 people work in HR Department from previous result. This implies that atleast half employee working in HR department do not have HR background. This important as there is more probability of Employees Retention is when they are working in domain of interest or as per their education background. Dissatisfaction with want we doing can be seen as major reason of leaving job.
#
#  . Most of Employees with Techanical degree are Bachelors.
#
#  . Most of Employees having Masters and Doctors belong to Life Science and Medical domain.
#
#  . R&D department almost everyone comes from profession or technical background except support staff. Factor like Salary Hike, travelling, overtime and Job level are things need to taken in consideration while analysing Attrition of this category.
#
#  . There are 159 Employee with Marketing background and all work in Sales Department.
#
#  . 50% Employees in sales department have background of Life sciences & Medical. So it will interesting to see attrition rate in these employees.

# %% [markdown]
# ### We will Analysis Attrition over above insight in next section of Job role.

# %% [markdown]
# ### Lets work with Job Role

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='JobRole',palette='Set1')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### . Before going for Attrition by Job role,

# %% [markdown]
# first build matrix of department vs job role which will give us idea about number of employees of different job role across department

# %%
pd.crosstab([df.JobRole],[df.Department], margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_6bbcb_row0_col0, #T_6bbcb_row0_col2, #T_6bbcb_row1_col1, #T_6bbcb_row1_col2, #T_6bbcb_row1_col3, #T_6bbcb_row2_col0, #T_6bbcb_row2_col2, #T_6bbcb_row4_col0, #T_6bbcb_row4_col2, #T_6bbcb_row5_col0, #T_6bbcb_row5_col2, #T_6bbcb_row6_col0, #T_6bbcb_row6_col2, #T_6bbcb_row7_col0, #T_6bbcb_row7_col1, #T_6bbcb_row8_col0, #T_6bbcb_row8_col1 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_6bbcb_row0_col1 {
#   background-color: #8600ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row0_col3, #T_6bbcb_row3_col1 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row1_col0 {
#   background-color: #ffc400;
#   color: #000000;
# }
# #T_6bbcb_row2_col1 {
#   background-color: #0033ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row2_col3 {
#   background-color: #7600ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row3_col0 {
#   background-color: #5000ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row3_col2, #T_6bbcb_row5_col1 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row3_col3 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_6bbcb_row4_col1 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row4_col3 {
#   background-color: #e800ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row5_col3, #T_6bbcb_row8_col3 {
#   background-color: #ff00da;
#   color: #f1f1f1;
# }
# #T_6bbcb_row6_col1 {
#   background-color: #0064ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row6_col3 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row7_col2 {
#   background-color: #b8ff00;
#   color: #000000;
# }
# #T_6bbcb_row7_col3 {
#   background-color: #3400ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row8_col2 {
#   background-color: #3f00ff;
#   color: #f1f1f1;
# }
# #T_6bbcb_row9_col0, #T_6bbcb_row9_col1, #T_6bbcb_row9_col2, #T_6bbcb_row9_col3 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6bbcb">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Department</th>
#       <th id="T_6bbcb_level0_col0" class="col_heading level0 col0" >Human Resources</th>
#       <th id="T_6bbcb_level0_col1" class="col_heading level0 col1" >Research & Development</th>
#       <th id="T_6bbcb_level0_col2" class="col_heading level0 col2" >Sales</th>
#       <th id="T_6bbcb_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bbcb_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <td id="T_6bbcb_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6bbcb_row0_col1" class="data row0 col1" >131</td>
#       <td id="T_6bbcb_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6bbcb_row0_col3" class="data row0 col3" >131</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <td id="T_6bbcb_row1_col0" class="data row1 col0" >52</td>
#       <td id="T_6bbcb_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_6bbcb_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6bbcb_row1_col3" class="data row1 col3" >52</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <td id="T_6bbcb_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_6bbcb_row2_col1" class="data row2 col1" >259</td>
#       <td id="T_6bbcb_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6bbcb_row2_col3" class="data row2 col3" >259</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row3" class="row_heading level0 row3" >Manager</th>
#       <td id="T_6bbcb_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_6bbcb_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_6bbcb_row3_col2" class="data row3 col2" >37</td>
#       <td id="T_6bbcb_row3_col3" class="data row3 col3" >102</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row4" class="row_heading level0 row4" >Manufacturing Director</th>
#       <td id="T_6bbcb_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_6bbcb_row4_col1" class="data row4 col1" >145</td>
#       <td id="T_6bbcb_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_6bbcb_row4_col3" class="data row4 col3" >145</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row5" class="row_heading level0 row5" >Research Director</th>
#       <td id="T_6bbcb_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_6bbcb_row5_col1" class="data row5 col1" >80</td>
#       <td id="T_6bbcb_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_6bbcb_row5_col3" class="data row5 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row6" class="row_heading level0 row6" >Research Scientist</th>
#       <td id="T_6bbcb_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_6bbcb_row6_col1" class="data row6 col1" >292</td>
#       <td id="T_6bbcb_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_6bbcb_row6_col3" class="data row6 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row7" class="row_heading level0 row7" >Sales Executive</th>
#       <td id="T_6bbcb_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_6bbcb_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_6bbcb_row7_col2" class="data row7 col2" >326</td>
#       <td id="T_6bbcb_row7_col3" class="data row7 col3" >326</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row8" class="row_heading level0 row8" >Sales Representative</th>
#       <td id="T_6bbcb_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_6bbcb_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_6bbcb_row8_col2" class="data row8 col2" >83</td>
#       <td id="T_6bbcb_row8_col3" class="data row8 col3" >83</td>
#     </tr>
#     <tr>
#       <th id="T_6bbcb_level0_row9" class="row_heading level0 row9" >All</th>
#       <td id="T_6bbcb_row9_col0" class="data row9 col0" >63</td>
#       <td id="T_6bbcb_row9_col1" class="data row9 col1" >961</td>
#       <td id="T_6bbcb_row9_col2" class="data row9 col2" >446</td>
#       <td id="T_6bbcb_row9_col3" class="data row9 col3" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comment:

# %% [markdown]
#  . There are 3 job role in HR Department, maximum of which are sales Executive with 446 Total Employees.
#
#  . Human Resources department has 2 Job role i.e. HR & Manager.
#
#  . There 6 different Job role in R&D department with total 961 employees and until now we know that all of them belong to thier respective domain background.

# %%
plt.figure(figsize=(12,10))
data=pd.crosstab(df['JobRole'], df['Attrition'])
data.div(data.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, 
                    color=['green', 'red'],figsize=(12,8))
plt.title('Attrition as per Job Role', fontsize=20)
plt.xlabel('Job Role',fontsize=15)
plt.show()

# %% [markdown]
# ### We all can definitely see Red Signal for different Managers & HR of Respective Job Role in above barplot !!!

# %% [markdown]
# Bar plot showing % attrition across each job role, let check absolute number matrix of attrition, again this time using crosstab.

# %%
pd.crosstab([df.JobRole,df.Department],[df.Attrition], margins=True).style.background_gradient(cmap='gist_rainbow_r')
# Out:
# <style type="text/css">
# #T_801e6_row0_col0, #T_801e6_row6_col2 {
#   background-color: #c200ff;
#   color: #f1f1f1;
# }
# #T_801e6_row0_col1 {
#   background-color: #ff00f0;
#   color: #f1f1f1;
# }
# #T_801e6_row0_col2 {
#   background-color: #cd00ff;
#   color: #f1f1f1;
# }
# #T_801e6_row1_col0 {
#   background-color: #ff00e0;
#   color: #f1f1f1;
# }
# #T_801e6_row1_col1, #T_801e6_row7_col2, #T_801e6_row10_col2 {
#   background-color: #fe00ff;
#   color: #f1f1f1;
# }
# #T_801e6_row1_col2, #T_801e6_row4_col2 {
#   background-color: #ff00e5;
#   color: #f1f1f1;
# }
# #T_801e6_row2_col0 {
#   background-color: #7000ff;
#   color: #f1f1f1;
# }
# #T_801e6_row2_col1 {
#   background-color: #0028ff;
#   color: #f1f1f1;
# }
# #T_801e6_row2_col2 {
#   background-color: #5500ff;
#   color: #f1f1f1;
# }
# #T_801e6_row3_col0, #T_801e6_row3_col1, #T_801e6_row3_col2 {
#   background-color: #ff00bf;
#   color: #f1f1f1;
# }
# #T_801e6_row4_col0, #T_801e6_row10_col0 {
#   background-color: #ff00eb;
#   color: #f1f1f1;
# }
# #T_801e6_row4_col1 {
#   background-color: #ff00d0;
#   color: #f1f1f1;
# }
# #T_801e6_row5_col0 {
#   background-color: #ff00da;
#   color: #f1f1f1;
# }
# #T_801e6_row5_col1, #T_801e6_row7_col1 {
#   background-color: #ff00ca;
#   color: #f1f1f1;
# }
# #T_801e6_row5_col2 {
#   background-color: #ff00d5;
#   color: #f1f1f1;
# }
# #T_801e6_row6_col0 {
#   background-color: #b700ff;
#   color: #f1f1f1;
# }
# #T_801e6_row6_col1 {
#   background-color: #ff00f6;
#   color: #f1f1f1;
# }
# #T_801e6_row7_col0 {
#   background-color: #f300ff;
#   color: #f1f1f1;
# }
# #T_801e6_row8_col0, #T_801e6_row8_col2 {
#   background-color: #3400ff;
#   color: #f1f1f1;
# }
# #T_801e6_row8_col1 {
#   background-color: #2f00ff;
#   color: #f1f1f1;
# }
# #T_801e6_row9_col0 {
#   background-color: #1900ff;
#   color: #f1f1f1;
# }
# #T_801e6_row9_col1 {
#   background-color: #000dff;
#   color: #f1f1f1;
# }
# #T_801e6_row9_col2 {
#   background-color: #1400ff;
#   color: #f1f1f1;
# }
# #T_801e6_row10_col1 {
#   background-color: #8100ff;
#   color: #f1f1f1;
# }
# #T_801e6_row11_col0, #T_801e6_row11_col1, #T_801e6_row11_col2 {
#   background-color: #ff0029;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_801e6">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Attrition</th>
#       <th id="T_801e6_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_801e6_level0_col1" class="col_heading level0 col1" >Yes</th>
#       <th id="T_801e6_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >JobRole</th>
#       <th class="index_name level1" >Department</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_801e6_level0_row0" class="row_heading level0 row0" >Healthcare Representative</th>
#       <th id="T_801e6_level1_row0" class="row_heading level1 row0" >Research & Development</th>
#       <td id="T_801e6_row0_col0" class="data row0 col0" >122</td>
#       <td id="T_801e6_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_801e6_row0_col2" class="data row0 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row1" class="row_heading level0 row1" >Human Resources</th>
#       <th id="T_801e6_level1_row1" class="row_heading level1 row1" >Human Resources</th>
#       <td id="T_801e6_row1_col0" class="data row1 col0" >40</td>
#       <td id="T_801e6_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_801e6_row1_col2" class="data row1 col2" >52</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row2" class="row_heading level0 row2" >Laboratory Technician</th>
#       <th id="T_801e6_level1_row2" class="row_heading level1 row2" >Research & Development</th>
#       <td id="T_801e6_row2_col0" class="data row2 col0" >197</td>
#       <td id="T_801e6_row2_col1" class="data row2 col1" >62</td>
#       <td id="T_801e6_row2_col2" class="data row2 col2" >259</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row3" class="row_heading level0 row3" rowspan="3">Manager</th>
#       <th id="T_801e6_level1_row3" class="row_heading level1 row3" >Human Resources</th>
#       <td id="T_801e6_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_801e6_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_801e6_row3_col2" class="data row3 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level1_row4" class="row_heading level1 row4" >Research & Development</th>
#       <td id="T_801e6_row4_col0" class="data row4 col0" >51</td>
#       <td id="T_801e6_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_801e6_row4_col2" class="data row4 col2" >54</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level1_row5" class="row_heading level1 row5" >Sales</th>
#       <td id="T_801e6_row5_col0" class="data row5 col0" >35</td>
#       <td id="T_801e6_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_801e6_row5_col2" class="data row5 col2" >37</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row6" class="row_heading level0 row6" >Manufacturing Director</th>
#       <th id="T_801e6_level1_row6" class="row_heading level1 row6" >Research & Development</th>
#       <td id="T_801e6_row6_col0" class="data row6 col0" >135</td>
#       <td id="T_801e6_row6_col1" class="data row6 col1" >10</td>
#       <td id="T_801e6_row6_col2" class="data row6 col2" >145</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row7" class="row_heading level0 row7" >Research Director</th>
#       <th id="T_801e6_level1_row7" class="row_heading level1 row7" >Research & Development</th>
#       <td id="T_801e6_row7_col0" class="data row7 col0" >78</td>
#       <td id="T_801e6_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_801e6_row7_col2" class="data row7 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row8" class="row_heading level0 row8" >Research Scientist</th>
#       <th id="T_801e6_level1_row8" class="row_heading level1 row8" >Research & Development</th>
#       <td id="T_801e6_row8_col0" class="data row8 col0" >245</td>
#       <td id="T_801e6_row8_col1" class="data row8 col1" >47</td>
#       <td id="T_801e6_row8_col2" class="data row8 col2" >292</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row9" class="row_heading level0 row9" >Sales Executive</th>
#       <th id="T_801e6_level1_row9" class="row_heading level1 row9" >Sales</th>
#       <td id="T_801e6_row9_col0" class="data row9 col0" >269</td>
#       <td id="T_801e6_row9_col1" class="data row9 col1" >57</td>
#       <td id="T_801e6_row9_col2" class="data row9 col2" >326</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row10" class="row_heading level0 row10" >Sales Representative</th>
#       <th id="T_801e6_level1_row10" class="row_heading level1 row10" >Sales</th>
#       <td id="T_801e6_row10_col0" class="data row10 col0" >50</td>
#       <td id="T_801e6_row10_col1" class="data row10 col1" >33</td>
#       <td id="T_801e6_row10_col2" class="data row10 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_801e6_level0_row11" class="row_heading level0 row11" >All</th>
#       <th id="T_801e6_level1_row11" class="row_heading level1 row11" ></th>
#       <td id="T_801e6_row11_col0" class="data row11 col0" >1233</td>
#       <td id="T_801e6_row11_col1" class="data row11 col1" >237</td>
#       <td id="T_801e6_row11_col2" class="data row11 col2" >1470</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Comment:

# %% [markdown]
#  . Percentage of attrition is high in Sales Representative,Laboratory Technician,Human Resources. This all job role comes at bottom in corparate hierachy also Salary is comparatively less compare to other job role.
#
#  . Monthly Income, Job stastifation, travelling are feature need to dive into for further insights in these job role.
#
#  . At the Top chart 62 Laboratory Technician has resign from job, followed by 57 sales executive and 47 Research Scientist.
#
#  . 16 % arttrition rate for Research Scientist, which involve huge investment from company. Company not only loses employee but its knowledge base, expertise & Intellatual property rights in some cases.

# %%
Numeric=['Age', 'DailyRate', 'DistanceFromHome',  
 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 
 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 
 'RelationshipSatisfaction','StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# ### Violinplot of Numeric Variables

# %%
Numeric_int=['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate','MonthlyIncome', 'MonthlyRate', 
             'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears','TrainingTimesLastYear',
             'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
sns.set_palette('spring')
plt.figure(figsize=(20,50), facecolor='white')
plotnumber =1

for i in Numeric_int:
    if plotnumber <=25:
        ax = plt.subplot(9,3,plotnumber)
        sns.violinplot(df[i])
        plt.xlabel(i,fontsize=20)
        plt.xticks(rotation=30)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comment:-

# %% [markdown]
#  . For Majority of people have spend 3 to 10 years at company.
#
#  . Most of people staying company upto 2 years after promotion.
#
#  . Majority of people are are train 2-3 times in last year.If employees leaves job then it loss investment for company.
#
#  . Majority of people stay in same role for maximum 4 yrs.
#
#  . Majority of Employees have salary hike of 10 to 15%.

# %% [markdown]
# ## Age Vs Attrition

# %%
plt.subplots(figsize=(12,6))
sns.countplot(data=df,x='Age',palette='Set1')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set_palette('hsv')
plt.subplots(figsize=(18,8))
sns.countplot(x='Age', hue='Attrition', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# ### Comment :-

# %% [markdown]
#  1. The Attrition rate is minimum between the Age years of 34 and 35.
#
#
#  2. The Attrition rate is maximum between the Age years of 29 and 31.

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=df,x='TotalWorkingYears',y='MonthlyIncome')
plt.xlabel('Total Working Years',fontsize=20)
plt.ylabel('Monthly Income',fontsize=20)
plt.title(" Total Working Years vs Monthly Income", fontsize=20)
plt.show()

# %% [markdown]
# ## Comment:-

# %% [markdown]
# Monthly Income is highest for the employees with 21 or more number of Total Working Years

# %%
plt.figure(figsize=(8,6))
sns.barplot(x='Attrition',y='MonthlyIncome',data=df)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.show()

# %% [markdown]
# ## Comment:-

# %% [markdown]
# The rate of Attrition is high when the employee did not got promoted since 1.8 years.

# %%
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %% [markdown]
# ## Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Attrition"] = le.fit_transform(df["Attrition"])
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
df.drop(["EmployeeCount", "EmployeeNumber", "Over18", "StandardHours"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1470, 31)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
def ordinal_encode(df, column):
    df[column] = oe.fit_transform(df[column])
    return df

oe_col = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
df=ordinal_encode(df, oe_col)
df.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1             2.0       1102         2.0                 1
# 1   49          0             1.0        279         1.0                 8
# 2   37          1             2.0       1373         1.0                 2
# 3   33          0             1.0       1392         1.0                 3
# 4   27          0             2.0        591         1.0                 2
#
#    Education  EducationField  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0          2             1.0                        2     0.0          94
# 1          1             1.0                        3     1.0          61
# 2          2             4.0                        4     1.0          92
# 3          4             1.0                        4     0.0          56
# 4          1             3.0                        1     1.0          40
#
#    JobInvolvement  JobLevel  JobRole  JobSatisfaction  MaritalStatus  \
# 0               3         2      7.0                4            2.0
# 1               2         2      6.0                2            1.0
# 2               2         1      2.0                3            2.0
# 3               3         1      6.0                3            1.0
# 4               3         1      2.0                2            1.0
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# 0           5993        19479                   8       1.0
# 1           5130        24907                   1       0.0
# 2           2090         2396                   6       1.0
# 3           2909        23159                   1       1.0
# 4           3468        16632                   9       0.0
#
#    PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 0                 11                  3                         1
# 1                 23                  4                         4
# 2                 15                  3                         2
# 3                 11                  3                         3
# 4                 12                  3                         4
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %% [markdown]
# ## Outliers Detection and Removal

# %%
plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numeric:
    if plotnumber<=28:
        ax=plt.subplot(7,4,plotnumber)
        sns.boxplot(df[column],color='g')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Features containing outliers

# %% [markdown]
# #### "MonthlyIncome", "NumCompaniesWorked", "PerformanceRating", "StockOptionLevel", "TotalWorkingYears", "TrainingTimesLastYear", "YearsAtCompany", "YearsInCurrentRole", "YearsSinceLastPromotion", "YearsWithCurrManager", "Attrition".

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (1470, 31)
# Shape of the dataframe after removing outliers:  (1387, 31)
# Percentage of data loss post outlier removal:  5.646258503401361

# %% [markdown]
# ## Data Loss

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((1470-1387)/1470)*100,'%')
# Out:
# Percentage Data Loss : 5.646258503401361 %

# %% [markdown]
# # Feature selection and Engineering

# %% [markdown]
# ### 1. Skewness of features

# %%
df.skew()
# Out:
# Age                         0.472280
# Attrition                   1.805983
# BusinessTravel             -1.426774
# DailyRate                  -0.017078
# Department                  0.183919
# DistanceFromHome            0.954752
# Education                  -0.289024
# EducationField              0.544868
# EnvironmentSatisfaction    -0.325285
# Gender                     -0.417296
# HourlyRate                 -0.030481
# JobInvolvement             -0.501401
# JobLevel                    1.126075
# JobRole                    -0.386843
# JobSatisfaction            -0.345612
# MaritalStatus              -0.160952
# MonthlyIncome               1.544770
# MonthlyRate                 0.030596
# NumCompaniesWorked          1.037715
# OverTime                    0.954751
# PercentSalaryHike           0.800592
# PerformanceRating           1.931566
# RelationshipSatisfaction   -0.295686
# StockOptionLevel            0.962332
# TotalWorkingYears           1.034487
# TrainingTimesLastYear       0.577614
# WorkLifeBalance            -0.557100
# YearsAtCompany              1.248623
# YearsInCurrentRole          0.726675
# YearsSinceLastPromotion     1.756335
# YearsWithCurrManager        0.694506
# dtype: float64

# %%
X= df.drop(['Attrition'],axis=1)
Y= df['Attrition']

# %%
from sklearn.preprocessing import power_transform
from sklearn.datasets import load_iris 

iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

skewness_before = X.skew()
print("Skewness before transformation:")
print(skewness_before)

X_transformed = power_transform(X, method='yeo-johnson')

X_transformed = pd.DataFrame(X_transformed, columns=X.columns)

skewness_after = X_transformed.skew()
print("\nSkewness after transformation:")
print(skewness_after)
# Out:
# Skewness before transformation:
# sepal length (cm)    0.314911
# sepal width (cm)     0.318966
# petal length (cm)   -0.274884
# petal width (cm)    -0.102967
# dtype: float64
#
# Skewness after transformation:
# sepal length (cm)    0.009869
# sepal width (cm)     0.000069
# petal length (cm)   -0.246515
# petal width (cm)    -0.156809
# dtype: float64

# %% [markdown]
# ### Transforming skew data using power transform

# %% [markdown]
# ### 2. Corrleation

# %%
df.corr()
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159366        0.022340   0.021946
# Attrition                -0.159366   1.000000       -0.001041  -0.057220
# BusinessTravel            0.022340  -0.001041        1.000000  -0.004606
# DailyRate                 0.021946  -0.057220       -0.004606   1.000000
# Department               -0.038242   0.063637       -0.003521  -0.005398
# DistanceFromHome         -0.011265   0.081788       -0.032873  -0.008171
# Education                 0.198502  -0.032703       -0.010560  -0.018442
# EducationField           -0.032676   0.023585        0.022576   0.040645
# EnvironmentSatisfaction   0.014098  -0.112393        0.001183   0.033123
# Gender                   -0.039430   0.036252       -0.025364  -0.005242
# HourlyRate                0.025465  -0.001532        0.025424   0.014279
# JobInvolvement            0.036424  -0.133957        0.028261   0.048004
# JobLevel                  0.453902  -0.171968        0.018996   0.022978
# JobRole                  -0.112957   0.064283        0.000213  -0.015437
# JobSatisfaction           0.011763  -0.114206       -0.032491   0.042698
# MaritalStatus            -0.104372   0.160960        0.018687  -0.074113
# MonthlyIncome             0.443747  -0.161848        0.033746   0.035004
# MonthlyRate               0.026954   0.014888       -0.010307  -0.029844
# NumCompaniesWorked        0.309209   0.050314        0.018764   0.032948
# OverTime                  0.034180   0.257237        0.022378   0.020294
# PercentSalaryHike         0.005891  -0.006267       -0.023004   0.027802
# PerformanceRating        -0.000617   0.010781       -0.018274   0.000574
# RelationshipSatisfaction  0.041744  -0.052344       -0.029660   0.004516
# StockOptionLevel          0.054506  -0.136676       -0.015159   0.048361
# TotalWorkingYears         0.636136  -0.185619        0.029818   0.046173
# TrainingTimesLastYear    -0.019008  -0.057285        0.010322   0.005861
# WorkLifeBalance          -0.016913  -0.062492       -0.014140  -0.044266
# YearsAtCompany            0.177620  -0.166455       -0.027164  -0.003580
# YearsInCurrentRole        0.121508  -0.171015       -0.029257   0.022899
# YearsSinceLastPromotion   0.103632  -0.029263       -0.027283  -0.043870
# YearsWithCurrManager      0.121747  -0.162297       -0.044321  -0.011516
#
#                           Department  DistanceFromHome  Education  \
# Age                        -0.038242         -0.011265   0.198502
# Attrition                   0.063637          0.081788  -0.032703
# BusinessTravel             -0.003521         -0.032873  -0.010560
# DailyRate                  -0.005398         -0.008171  -0.018442
# Department                  1.000000          0.023919   0.012846
# DistanceFromHome            0.023919          1.000000   0.001084
# Education                   0.012846          0.001084   1.000000
# EducationField              0.013432          0.005882  -0.038017
# EnvironmentSatisfaction    -0.014540         -0.019279  -0.026223
# Gender                     -0.030618         -0.000819  -0.019166
# HourlyRate                 -0.002412          0.028230   0.010848
# JobInvolvement             -0.024040          0.010106   0.041343
# JobLevel                    0.126809          0.008498   0.083065
# JobRole                     0.678627         -0.000537   0.015140
# JobSatisfaction             0.029521         -0.009284  -0.007219
# MaritalStatus               0.052086         -0.021816  -0.012726
# MonthlyIncome               0.071876         -0.015040   0.072670
# MonthlyRate                 0.022741          0.037052  -0.018540
# NumCompaniesWorked         -0.044344         -0.028307   0.130812
# OverTime                    0.014908          0.026520  -0.017166
# PercentSalaryHike          -0.022678          0.035864  -0.011344
# PerformanceRating          -0.039364          0.023678  -0.023487
# RelationshipSatisfaction   -0.037705          0.007885  -0.002393
# StockOptionLevel           -0.003424          0.049976   0.028494
# TotalWorkingYears          -0.016246         -0.001092   0.125613
# TrainingTimesLastYear       0.036092         -0.034386  -0.026879
# WorkLifeBalance             0.026978         -0.034398   0.007844
# YearsAtCompany              0.032583          0.011579   0.033313
# YearsInCurrentRole          0.065536          0.019039   0.058007
# YearsSinceLastPromotion     0.048931          0.006635   0.042517
# YearsWithCurrManager        0.034216         -0.000221   0.031210
#
#                           EducationField  EnvironmentSatisfaction    Gender  \
# Age                            -0.032676                 0.014098 -0.039430
# Attrition                       0.023585                -0.112393  0.036252
# BusinessTravel                  0.022576                 0.001183 -0.025364
# DailyRate                       0.040645                 0.033123 -0.005242
# Department                      0.013432                -0.014540 -0.030618
# DistanceFromHome                0.005882                -0.019279 -0.000819
# Education                      -0.038017                -0.026223 -0.019166
# EducationField                  1.000000                 0.047924  0.010676
# EnvironmentSatisfaction         0.047924                 1.000000 -0.015715
# Gender                          0.010676                -0.015715  1.000000
# HourlyRate                     -0.006539                -0.040459  0.004768
# JobInvolvement                 -0.006876                -0.012720  0.011939
# JobLevel                       -0.035795                 0.013835 -0.056970
# JobRole                         0.017492                -0.022354 -0.036831
# JobSatisfaction                -0.050934                -0.011186  0.036302
# MaritalStatus                   0.012073                -0.012453 -0.056786
# MonthlyIncome                  -0.030017                 0.003011 -0.047362
# MonthlyRate                    -0.023384                 0.032916 -0.045850
# NumCompaniesWorked              0.001983                 0.015298 -0.030920
# OverTime                        0.007912                 0.059355 -0.051558
# PercentSalaryHike              -0.007845                -0.026797  0.005443
# PerformanceRating              -0.003621                -0.025299 -0.010757
# RelationshipSatisfaction       -0.013734                 0.018414  0.041458
# StockOptionLevel               -0.015355                 0.013330  0.026438
# TotalWorkingYears              -0.012375                -0.001669 -0.058555
# TrainingTimesLastYear           0.050502                -0.019318 -0.040211
# WorkLifeBalance                 0.034038                 0.032492  0.000134
# YearsAtCompany                 -0.012950                 0.006621 -0.045123
# YearsInCurrentRole             -0.010614                 0.038837 -0.025536
# YearsSinceLastPromotion         0.034094                 0.027943 -0.028162
# YearsWithCurrManager            0.013437                 0.001606 -0.036280
#
#                           HourlyRate  JobInvolvement  JobLevel   JobRole  \
# Age                         0.025465        0.036424  0.453902 -0.112957
# Attrition                  -0.001532       -0.133957 -0.171968  0.064283
# BusinessTravel              0.025424        0.028261  0.018996  0.000213
# DailyRate                   0.014279        0.048004  0.022978 -0.015437
# Department                 -0.002412       -0.024040  0.126809  0.678627
# DistanceFromHome            0.028230        0.010106  0.008498 -0.000537
# Education                   0.010848        0.041343  0.083065  0.015140
# EducationField             -0.006539       -0.006876 -0.035795  0.017492
# EnvironmentSatisfaction    -0.040459       -0.012720  0.013835 -0.022354
# Gender                      0.004768        0.011939 -0.056970 -0.036831
# HourlyRate                  1.000000        0.049577 -0.034507 -0.024404
# JobInvolvement              0.049577        1.000000 -0.005280  0.007655
# JobLevel                   -0.034507       -0.005280  1.000000 -0.067968
# JobRole                    -0.024404        0.007655 -0.067968  1.000000
# JobSatisfaction            -0.069016        0.003910  0.014973  0.015361
# MaritalStatus              -0.007768       -0.044455 -0.067931  0.063149
# MonthlyIncome              -0.024587       -0.010269  0.940948 -0.077012
# MonthlyRate                -0.011663       -0.005142  0.043085  0.002271
# NumCompaniesWorked          0.019187        0.011934  0.155141 -0.067264
# OverTime                   -0.004304        0.000837  0.005305  0.043027
# PercentSalaryHike          -0.015490       -0.016065 -0.029366  0.001921
# PerformanceRating          -0.006088       -0.026693 -0.021065 -0.020509
# RelationshipSatisfaction    0.005532        0.037020  0.014398 -0.024408
# StockOptionLevel            0.041972        0.023160  0.018698 -0.015274
# TotalWorkingYears          -0.009929        0.001788  0.752489 -0.132158
# TrainingTimesLastYear      -0.014778       -0.009103 -0.019223  0.002137
# WorkLifeBalance            -0.010359       -0.006875  0.044859  0.019427
# YearsAtCompany             -0.026974        0.003191  0.418382 -0.043248
# YearsInCurrentRole         -0.032875        0.012514  0.297038 -0.003287
# YearsSinceLastPromotion    -0.050165       -0.014229  0.216612 -0.002902
# YearsWithCurrManager       -0.018562        0.029998  0.302023 -0.017225
#
#                           JobSatisfaction  MaritalStatus  MonthlyIncome  \
# Age                              0.011763      -0.104372       0.443747
# Attrition                       -0.114206       0.160960      -0.161848
# BusinessTravel                  -0.032491       0.018687       0.033746
# DailyRate                        0.042698      -0.074113       0.035004
# Department                       0.029521       0.052086       0.071876
# DistanceFromHome                -0.009284      -0.021816      -0.015040
# Education                       -0.007219      -0.012726       0.072670
# EducationField                  -0.050934       0.012073      -0.030017
# EnvironmentSatisfaction         -0.011186      -0.012453       0.003011
# Gender                           0.036302      -0.056786      -0.047362
# HourlyRate                      -0.069016      -0.007768      -0.024587
# JobInvolvement                   0.003910      -0.044455      -0.010269
# JobLevel                         0.014973      -0.067931       0.940948
# JobRole                          0.015361       0.063149      -0.077012
# JobSatisfaction                  1.000000       0.022490       0.011954
# MaritalStatus                    0.022490       1.000000      -0.064885
# MonthlyIncome                    0.011954      -0.064885       1.000000
# MonthlyRate                     -0.007395       0.029546       0.042510
# NumCompaniesWorked              -0.049796      -0.041353       0.168618
# OverTime                         0.025022      -0.014745       0.014046
# PercentSalaryHike                0.017402       0.012709      -0.022710
# PerformanceRating                0.003409       0.005893      -0.016518
# RelationshipSatisfaction        -0.010531       0.023225       0.022203
# StockOptionLevel                 0.008988      -0.663052       0.008439
# TotalWorkingYears                0.002978      -0.086909       0.741363
# TrainingTimesLastYear           -0.011365       0.016893      -0.025888
# WorkLifeBalance                 -0.024311       0.018141       0.032167
# YearsAtCompany                   0.029345      -0.046321       0.380543
# YearsInCurrentRole               0.021082      -0.056760       0.260340
# YearsSinceLastPromotion          0.019533      -0.013044       0.196282
# YearsWithCurrManager             0.002675      -0.043572       0.259423
#
#                           MonthlyRate  NumCompaniesWorked  OverTime  \
# Age                          0.026954            0.309209  0.034180
# Attrition                    0.014888            0.050314  0.257237
# BusinessTravel              -0.010307            0.018764  0.022378
# DailyRate                   -0.029844            0.032948  0.020294
# Department                   0.022741           -0.044344  0.014908
# DistanceFromHome             0.037052           -0.028307  0.026520
# Education                   -0.018540            0.130812 -0.017166
# EducationField              -0.023384            0.001983  0.007912
# EnvironmentSatisfaction      0.032916            0.015298  0.059355
# Gender                      -0.045850           -0.030920 -0.051558
# HourlyRate                  -0.011663            0.019187 -0.004304
# JobInvolvement              -0.005142            0.011934  0.000837
# JobLevel                     0.043085            0.155141  0.005305
# JobRole                      0.002271           -0.067264  0.043027
# JobSatisfaction             -0.007395           -0.049796  0.025022
# MaritalStatus                0.029546           -0.041353 -0.014745
# MonthlyIncome                0.042510            0.168618  0.014046
# MonthlyRate                  1.000000            0.016440  0.005552
# NumCompaniesWorked           0.016440            1.000000 -0.020059
# OverTime                     0.005552           -0.020059  1.000000
# PercentSalaryHike           -0.013630           -0.005976 -0.000886
# PerformanceRating           -0.020675           -0.011690  0.011654
# RelationshipSatisfaction    -0.005290            0.048606  0.048832
# StockOptionLevel            -0.038998            0.035681 -0.000756
# TotalWorkingYears            0.017482            0.273155  0.017335
# TrainingTimesLastYear        0.024648           -0.068857 -0.081081
# WorkLifeBalance              0.002295            0.000979 -0.032425
# YearsAtCompany              -0.033970           -0.141535 -0.019568
# YearsInCurrentRole          -0.008861           -0.115930 -0.021968
# YearsSinceLastPromotion     -0.010779           -0.064930 -0.004751
# YearsWithCurrManager        -0.033466           -0.128915 -0.031931
#
#                           PercentSalaryHike  PerformanceRating  \
# Age                                0.005891          -0.000617
# Attrition                         -0.006267           0.010781
# BusinessTravel                    -0.023004          -0.018274
# DailyRate                          0.027802           0.000574
# Department                        -0.022678          -0.039364
# DistanceFromHome                   0.035864           0.023678
# Education                         -0.011344          -0.023487
# EducationField                    -0.007845          -0.003621
# EnvironmentSatisfaction           -0.026797          -0.025299
# Gender                             0.005443          -0.010757
# HourlyRate                        -0.015490          -0.006088
# JobInvolvement                    -0.016065          -0.026693
# JobLevel                          -0.029366          -0.021065
# JobRole                            0.001921          -0.020509
# JobSatisfaction                    0.017402           0.003409
# MaritalStatus                      0.012709           0.005893
# MonthlyIncome                     -0.022710          -0.016518
# MonthlyRate                       -0.013630          -0.020675
# NumCompaniesWorked                -0.005976          -0.011690
# OverTime                          -0.000886           0.011654
# PercentSalaryHike                  1.000000           0.768868
# PerformanceRating                  0.768868           1.000000
# RelationshipSatisfaction          -0.037246          -0.028131
# StockOptionLevel                   0.004454           0.002938
# TotalWorkingYears                 -0.019235           0.003876
# TrainingTimesLastYear             -0.008951          -0.016177
# WorkLifeBalance                   -0.011006           0.003659
# YearsAtCompany                    -0.030377           0.008069
# YearsInCurrentRole                -0.011269           0.021699
# YearsSinceLastPromotion           -0.034832           0.006845
# YearsWithCurrManager              -0.011293           0.019275
#
#                           RelationshipSatisfaction  StockOptionLevel  \
# Age                                       0.041744          0.054506
# Attrition                                -0.052344         -0.136676
# BusinessTravel                           -0.029660         -0.015159
# DailyRate                                 0.004516          0.048361
# Department                               -0.037705         -0.003424
# DistanceFromHome                          0.007885          0.049976
# Education                                -0.002393          0.028494
# EducationField                           -0.013734         -0.015355
# EnvironmentSatisfaction                   0.018414          0.013330
# Gender                                    0.041458          0.026438
# HourlyRate                                0.005532          0.041972
# JobInvolvement                            0.037020          0.023160
# JobLevel                                  0.014398          0.018698
# JobRole                                  -0.024408         -0.015274
# JobSatisfaction                          -0.010531          0.008988
# MaritalStatus                             0.023225         -0.663052
# MonthlyIncome                             0.022203          0.008439
# MonthlyRate                              -0.005290         -0.038998
# NumCompaniesWorked                        0.048606          0.035681
# OverTime                                  0.048832         -0.000756
# PercentSalaryHike                        -0.037246          0.004454
# PerformanceRating                        -0.028131          0.002938
# RelationshipSatisfaction                  1.000000         -0.046612
# StockOptionLevel                         -0.046612          1.000000
# TotalWorkingYears                         0.006388          0.027590
# TrainingTimesLastYear                     0.001240          0.016626
# WorkLifeBalance                           0.023191          0.003430
# YearsAtCompany                           -0.014690          0.033043
# YearsInCurrentRole                       -0.030128          0.060600
# YearsSinceLastPromotion                  -0.011251          0.022084
# YearsWithCurrManager                     -0.014141          0.048192
#
#                           TotalWorkingYears  TrainingTimesLastYear  \
# Age                                0.636136              -0.019008
# Attrition                         -0.185619              -0.057285
# BusinessTravel                     0.029818               0.010322
# DailyRate                          0.046173               0.005861
# Department                        -0.016246               0.036092
# DistanceFromHome                  -0.001092              -0.034386
# Education                          0.125613              -0.026879
# EducationField                    -0.012375               0.050502
# EnvironmentSatisfaction           -0.001669              -0.019318
# Gender                            -0.058555              -0.040211
# HourlyRate                        -0.009929              -0.014778
# JobInvolvement                     0.001788              -0.009103
# JobLevel                           0.752489              -0.019223
# JobRole                           -0.132158               0.002137
# JobSatisfaction                    0.002978              -0.011365
# MaritalStatus                     -0.086909               0.016893
# MonthlyIncome                      0.741363              -0.025888
# MonthlyRate                        0.017482               0.024648
# NumCompaniesWorked                 0.273155              -0.068857
# OverTime                           0.017335              -0.081081
# PercentSalaryHike                 -0.019235              -0.008951
# PerformanceRating                  0.003876              -0.016177
# RelationshipSatisfaction           0.006388               0.001240
# StockOptionLevel                   0.027590               0.016626
# TotalWorkingYears                  1.000000              -0.033750
# TrainingTimesLastYear             -0.033750               1.000000
# WorkLifeBalance                    0.011362               0.032070
# YearsAtCompany                     0.490539               0.001604
# YearsInCurrentRole                 0.367255               0.002912
# YearsSinceLastPromotion            0.249712               0.021902
# YearsWithCurrManager               0.378519               0.001316
#
#                           WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Age                             -0.016913        0.177620            0.121508
# Attrition                       -0.062492       -0.166455           -0.171015
# BusinessTravel                  -0.014140       -0.027164           -0.029257
# DailyRate                       -0.044266       -0.003580            0.022899
# Department                       0.026978        0.032583            0.065536
# DistanceFromHome                -0.034398        0.011579            0.019039
# Education                        0.007844        0.033313            0.058007
# EducationField                   0.034038       -0.012950           -0.010614
# EnvironmentSatisfaction          0.032492        0.006621            0.038837
# Gender                           0.000134       -0.045123           -0.025536
# HourlyRate                      -0.010359       -0.026974           -0.032875
# JobInvolvement                  -0.006875        0.003191            0.012514
# JobLevel                         0.044859        0.418382            0.297038
# JobRole                          0.019427       -0.043248           -0.003287
# JobSatisfaction                 -0.024311        0.029345            0.021082
# MaritalStatus                    0.018141       -0.046321           -0.056760
# MonthlyIncome                    0.032167        0.380543            0.260340
# MonthlyRate                      0.002295       -0.033970           -0.008861
# NumCompaniesWorked               0.000979       -0.141535           -0.115930
# OverTime                        -0.032425       -0.019568           -0.021968
# PercentSalaryHike               -0.011006       -0.030377           -0.011269
# PerformanceRating                0.003659        0.008069            0.021699
# RelationshipSatisfaction         0.023191       -0.014690           -0.030128
# StockOptionLevel                 0.003430        0.033043            0.060600
# TotalWorkingYears                0.011362        0.490539            0.367255
# TrainingTimesLastYear            0.032070        0.001604            0.002912
# WorkLifeBalance                  1.000000        0.022394            0.038592
# YearsAtCompany                   0.022394        1.000000            0.793691
# YearsInCurrentRole               0.038592        0.793691            1.000000
# YearsSinceLastPromotion          0.012377        0.522540            0.495178
# YearsWithCurrManager             0.003233        0.820255            0.732353
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.103632              0.121747
# Attrition                               -0.029263             -0.162297
# BusinessTravel                          -0.027283             -0.044321
# DailyRate                               -0.043870             -0.011516
# Department                               0.048931              0.034216
# DistanceFromHome                         0.006635             -0.000221
# Education                                0.042517              0.031210
# EducationField                           0.034094              0.013437
# EnvironmentSatisfaction                  0.027943              0.001606
# Gender                                  -0.028162             -0.036280
# HourlyRate                              -0.050165             -0.018562
# JobInvolvement                          -0.014229              0.029998
# JobLevel                                 0.216612              0.302023
# JobRole                                 -0.002902             -0.017225
# JobSatisfaction                          0.019533              0.002675
# MaritalStatus                           -0.013044             -0.043572
# MonthlyIncome                            0.196282              0.259423
# MonthlyRate                             -0.010779             -0.033466
# NumCompaniesWorked                      -0.064930             -0.128915
# OverTime                                -0.004751             -0.031931
# PercentSalaryHike                       -0.034832             -0.011293
# PerformanceRating                        0.006845              0.019275
# RelationshipSatisfaction                -0.011251             -0.014141
# StockOptionLevel                         0.022084              0.048192
# TotalWorkingYears                        0.249712              0.378519
# TrainingTimesLastYear                    0.021902              0.001316
# WorkLifeBalance                          0.012377              0.003233
# YearsAtCompany                           0.522540              0.820255
# YearsInCurrentRole                       0.495178              0.732353
# YearsSinceLastPromotion                  1.000000              0.482014
# YearsWithCurrManager                     0.482014              1.000000

# %%
upper_triangle = np.triu(df.corr())
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df1.corr()['Attrition'].drop(['Attrition']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Attrition',fontsize=15)
plt.title('Correlation of features with Target Variable Attrition',fontsize = 18)
plt.show()

# %% [markdown]
# # Comment:-

# %% [markdown]
#  . Age, JobLevel, MonthlyIncome is highly positively correlated with TotalWorkingYears.
#
#  . JobLevel is highly positively correlated with the MonthlyIncome.
#
#  . PercentSalaryHike is highly positively correlated with the column PerformanceRating.

# %% [markdown]
# # 3. Checking Multicollinearity between features using variance_inflation_factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
vif['Features']= df.columns
vif
# Out:
#            VIF                  Features
# 0    30.994586                       Age
# 1     1.520532                 Attrition
# 2     6.669133            BusinessTravel
# 3     5.041636                 DailyRate
# 4    13.932479                Department
# 5     2.342119          DistanceFromHome
# 6     9.343006                 Education
# 7     3.892970            EducationField
# 8     7.283358   EnvironmentSatisfaction
# 9     2.547848                    Gender
# 10   11.306297                HourlyRate
# 11   15.400467            JobInvolvement
# 12   47.731443                  JobLevel
# 13    8.471108                   JobRole
# 14    7.218561           JobSatisfaction
# 15    5.916058             MaritalStatus
# 16   28.201936             MonthlyIncome
# 17    5.099890               MonthlyRate
# 18    2.745374        NumCompaniesWorked
# 19    1.571682                  OverTime
# 20   42.792167         PercentSalaryHike
# 21  124.247397         PerformanceRating
# 22    7.249326  RelationshipSatisfaction
# 23    3.329164          StockOptionLevel
# 24   12.901873         TotalWorkingYears
# 25    5.740010     TrainingTimesLastYear
# 26   15.682032           WorkLifeBalance
# 27   13.161911            YearsAtCompany
# 28    7.256937        YearsInCurrentRole
# 29    2.175404   YearsSinceLastPromotion
# 30    7.855613      YearsWithCurrManager

# %% [markdown]
# ## Commet:-

# %% [markdown]
#  . We can see that multicollinerity is within permissible limit of 10.

# %% [markdown]
# ### Balancing using SMOTE

# %% [markdown]
# As data is Imbalanced in nature we will need to balance target variable.

# %%
# !pip install --upgrade scikit-learn
# !pip install --upgrade imbalanced-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: imbalanced-learn in c:\anaconda3\lib\site-packages (0.7.0)
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# Collecting imbalanced-learn
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/92/e8/86c36e1b13007ca9c89381adac6c078cfc8fb71841a76c08a3fe3eca91d3/imbalanced_learn-0.12.0-py3-none-any.whl.metadata
#   Using cached imbalanced_learn-0.12.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\anaconda3\lib\site-packages (from imbalanced-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\anaconda3\lib\site-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Using cached imbalanced_learn-0.12.0-py3-none-any.whl (257 kB)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.7.0
#     Uninstalling imbalanced-learn-0.7.0:
#       Successfully uninstalled imbalanced-learn-0.7.0
# Successfully installed imbalanced-learn-0.12.0

# %%
# !pip install imbalanced-learn==0.7.0
# Out:
# Collecting imbalanced-learn==0.7.0
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# Requirement already satisfied: numpy>=1.13.3 in c:\anaconda3\lib\site-packages (from imbalanced-learn==0.7.0) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\anaconda3\lib\site-packages (from imbalanced-learn==0.7.0) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.23 in c:\anaconda3\lib\site-packages (from imbalanced-learn==0.7.0) (1.4.0)
# Requirement already satisfied: joblib>=0.11 in c:\anaconda3\lib\site-packages (from imbalanced-learn==0.7.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\anaconda3\lib\site-packages (from scikit-learn>=0.23->imbalanced-learn==0.7.0) (2.2.0)
# Installing collected packages: imbalanced-learn
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.12.0
#     Uninstalling imbalanced-learn-0.12.0:
#       Successfully uninstalled imbalanced-learn-0.12.0
# Successfully installed imbalanced-learn-0.7.0
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Anaconda3\Lib\site-packages\pandas-2.1.4.dist-info due to invalid metadata entry 'name'

# %%
from imblearn.over_sampling import SMOTE

# %%
num_samples = min(X.shape[0], Y.shape[0])
X = X[:num_samples]
Y = Y[:num_samples]

# %%
assert X.shape[0] == Y.shape[0], "Number of samples in X and Y must be consistent"

oversample = SMOTE(random_state=42)
X_resampled, Y_resampled = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# Attrition
# 0    126
# 1     24
# Name: count, dtype: int64

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA()
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
x=df1.drop(columns= ['Attrition'])
y=df1['Attrition']

# %%
pca_new = PCA(n_components=4)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(4))

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier

# %%
print("Shape of principle_x:", principle_x.shape)
print("Shape of Y:", Y.shape)
# Out:
# Shape of principle_x: (150, 4)
# Shape of Y: (150,)

# %%
principle_x = principle_x.iloc[:Y.shape[0], :]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (100, 4)
# Training target vector size: (100,)
# Test feature matrix size: (50, 4)
# Test target vector size: (50,)

# %% [markdown]
# # Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.33, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.92 on Random_state 42

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=242, test_size=.33)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.86
#
#
# Confusion matrix of Logistics Regression :
#  [[43  0]
#  [ 7  0]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        43
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.86        50
#    macro avg       0.43      0.50      0.46        50
# weighted avg       0.74      0.86      0.80        50

# %% [markdown]
# # Finding Optimal value of n_neighbors for KNN

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(30):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.5291502622129182
# RMSE value for k=  2 is: 0.4
# RMSE value for k=  3 is: 0.4
# RMSE value for k=  4 is: 0.4
# RMSE value for k=  5 is: 0.4242640687119285
# RMSE value for k=  6 is: 0.37416573867739417
# RMSE value for k=  7 is: 0.34641016151377546
# RMSE value for k=  8 is: 0.37416573867739417
# RMSE value for k=  9 is: 0.37416573867739417
# RMSE value for k=  10 is: 0.37416573867739417
# RMSE value for k=  11 is: 0.37416573867739417
# RMSE value for k=  12 is: 0.37416573867739417
# RMSE value for k=  13 is: 0.37416573867739417
# RMSE value for k=  14 is: 0.37416573867739417
# RMSE value for k=  15 is: 0.37416573867739417
# RMSE value for k=  16 is: 0.37416573867739417
# RMSE value for k=  17 is: 0.37416573867739417
# RMSE value for k=  18 is: 0.37416573867739417
# RMSE value for k=  19 is: 0.37416573867739417
# RMSE value for k=  20 is: 0.37416573867739417
# RMSE value for k=  21 is: 0.37416573867739417
# RMSE value for k=  22 is: 0.37416573867739417
# RMSE value for k=  23 is: 0.37416573867739417
# RMSE value for k=  24 is: 0.37416573867739417
# RMSE value for k=  25 is: 0.37416573867739417
# RMSE value for k=  26 is: 0.37416573867739417
# RMSE value for k=  27 is: 0.37416573867739417
# RMSE value for k=  28 is: 0.37416573867739417
# RMSE value for k=  29 is: 0.37416573867739417
# RMSE value for k=  30 is: 0.37416573867739417

# %%
plt.figure(figsize = (8,6))
plt.plot(range(30), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# # Applying other classification algorithm

# %%
model=[
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 22),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('============================================================================================================')
# Out:
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.86
#
#
# Confusion matrix :
#  [[43  0]
#  [ 7  0]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        43
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.86        50
#    macro avg       0.43      0.50      0.46        50
# weighted avg       0.74      0.86      0.80        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.84
#
#
# Confusion matrix :
#  [[41  2]
#  [ 6  1]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91        43
#            1       0.33      0.14      0.20         7
#
#     accuracy                           0.84        50
#    macro avg       0.60      0.55      0.56        50
# weighted avg       0.80      0.84      0.81        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.66
#
#
# Confusion matrix :
#  [[31 12]
#  [ 5  2]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78        43
#            1       0.14      0.29      0.19         7
#
#     accuracy                           0.66        50
#    macro avg       0.50      0.50      0.49        50
# weighted avg       0.76      0.66      0.70        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=22) is
#
#
# Accuracy Score :
#  0.86
#
#
# Confusion matrix :
#  [[43  0]
#  [ 7  0]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        43
#            1       0.00      0.00      0.00         7
#
#     accuracy                           0.86        50
#    macro avg       0.43      0.50      0.46        50
# weighted avg       0.74      0.86      0.80        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.78
#
#
# Confusion matrix :
#  [[37  6]
#  [ 5  2]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        43
#            1       0.25      0.29      0.27         7
#
#     accuracy                           0.78        50
#    macro avg       0.57      0.57      0.57        50
# weighted avg       0.79      0.78      0.79        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix AdaBoostClassifier() is
#
#
# Accuracy Score :
#  0.84
#
#
# Confusion matrix :
#  [[39  4]
#  [ 4  3]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        43
#            1       0.43      0.43      0.43         7
#
#     accuracy                           0.84        50
#    macro avg       0.67      0.67      0.67        50
# weighted avg       0.84      0.84      0.84        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix GradientBoostingClassifier() is
#
#
# Accuracy Score :
#  0.76
#
#
# Confusion matrix :
#  [[36  7]
#  [ 5  2]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86        43
#            1       0.22      0.29      0.25         7
#
#     accuracy                           0.76        50
#    macro avg       0.55      0.56      0.55        50
# weighted avg       0.79      0.76      0.77        50
#
#
#
# ============================================================================================================
# Classification ML Algorithm Evaluation Matrix BaggingClassifier() is
#
#
# Accuracy Score :
#  0.78
#
#
# Confusion matrix :
#  [[37  6]
#  [ 5  2]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87        43
#            1       0.25      0.29      0.27         7
#
#     accuracy                           0.78        50
#    macro avg       0.57      0.57      0.57        50
# weighted avg       0.79      0.78      0.79        50
#
#
#
# ============================================================================================================

# %% [markdown]
# ### We can see that RandomForestClassifier() gives us good Accuracy and maximum f1 score. so we will continue further investigation with crossvalidation of above model

# %% [markdown]
# #

# %% [markdown]
# # Cross Validation:-

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 12),
        RandomForestClassifier(),
        AdaBoostClassifier(),
        GradientBoostingClassifier(),
        BaggingClassifier()]

for m in model:
    score = cross_val_score(m, X, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('============================================================================================================')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.83333333 0.83333333 0.83333333 0.83333333 0.86666667]
# Mean Score : 0.8400000000000001
# Std deviation : 0.01333333333333333
#
#
# ============================================================================================================
#
#
# Cross Validation Score SVC() :
#
# Score : [0.83333333 0.83333333 0.83333333 0.83333333 0.86666667]
# Mean Score : 0.8400000000000001
# Std deviation : 0.01333333333333333
#
#
# ============================================================================================================
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.16666667 0.9        0.83333333 0.83333333 0.86666667]
# Mean Score : 0.72
# Std deviation : 0.2777688887466621
#
#
# ============================================================================================================
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.7        0.63333333 0.8        0.73333333 0.56666667]
# Mean Score : 0.6866666666666668
# Std deviation : 0.08055363982396382
#
#
# ============================================================================================================
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=12) :
#
# Score : [0.83333333 0.83333333 0.83333333 0.83333333 0.86666667]
# Mean Score : 0.8400000000000001
# Std deviation : 0.01333333333333333
#
#
# ============================================================================================================
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.76666667 0.83333333 0.83333333 0.76666667 0.76666667]
# Mean Score : 0.7933333333333333
# Std deviation : 0.03265986323710904
#
#
# ============================================================================================================
#
#
# Cross Validation Score AdaBoostClassifier() :
#
# Score : [0.7        0.8        0.8        0.73333333 0.73333333]
# Mean Score : 0.7533333333333333
# Std deviation : 0.04000000000000004
#
#
# ============================================================================================================
#
#
# Cross Validation Score GradientBoostingClassifier() :
#
# Score : [0.7        0.76666667 0.8        0.73333333 0.66666667]
# Mean Score : 0.7333333333333333
# Std deviation : 0.0471404520791032
#
#
# ============================================================================================================
#
#
# Cross Validation Score BaggingClassifier() :
#
# Score : [0.73333333 0.8        0.83333333 0.73333333 0.83333333]
# Mean Score : 0.7866666666666667
# Std deviation : 0.045215533220835165
#
#
# ============================================================================================================

# %% [markdown]
# #### On basis of maximum score in crossvalidation of Random Forest Classifier. we will apply Hyperparameter tuning on Random Forest model

# %% [markdown]
# # Hyper Parameter Tuning : GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter = {  'bootstrap': [True], 'max_depth': [5, 10,20,40,50, None], 
              'max_features': ['auto', 'log2'], 
              'criterion':['gini','entropy'],
              'n_estimators': [5, 10, 15 ,25,50,100]}

# %%
GCV = GridSearchCV(RandomForestClassifier(),parameter,cv=5,n_jobs = -1,verbose=3)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 40, 50, None],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [5, 10, 15, 25, 50, 100]},
#              verbose=3)

# %%
GCV.best_params_
# Out:
# {'bootstrap': True,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'n_estimators': 15}

# %% [markdown]
# # Final Model

# %%
Final_mod = RandomForestClassifier(bootstrap=True,criterion='entropy',n_estimators= 25, max_depth=20 ,max_features='log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.86

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

y_pred_prob = Final_mod.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(Y_test,y_pred_prob)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr, label='Random Forest Classifier')
plt.xlabel('False postive rate')
plt.ylabel('True postive rate')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.6196013289036545

# %% [markdown]
# # Saving model

# %%
import joblib
joblib.dump(Final_mod,'IBM_HR_Analytics_Final.pkl')
# Out:
# ['IBM_HR_Analytics_Final.pkl']
